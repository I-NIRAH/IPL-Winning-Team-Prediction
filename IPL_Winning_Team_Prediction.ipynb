# %% [markdown]
# <a href="https://colab.research.google.com/github/I-NIRAH/IPL-Winning-Team-Prediction/blob/main/IPL_Winning_Team_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
deliveries=pd.read_csv('/content/deliveries.csv.zip')
matches=pd.read_csv('/content/matches.csv')

# %%
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
matches.shape
# Out:
# (756, 18)

# %%
deliveries.shape
# Out:
# (179078, 21)

# %%
total_score=deliveries.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
print(total_score)
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
match=matches.merge(total_score[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match
# Out:
#          id    Season           city        date                team1  \
# 0         1  IPL-2017      Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1         1  IPL-2017      Hyderabad  05-04-2017  Sunrisers Hyderabad
# 2         2  IPL-2017           Pune  06-04-2017       Mumbai Indians
# 3         2  IPL-2017           Pune  06-04-2017       Mumbai Indians
# 4         3  IPL-2017         Rajkot  07-04-2017        Gujarat Lions
# ...     ...       ...            ...         ...                  ...
# 1523  11413  IPL-2019  Visakhapatnam  08-05-2019  Sunrisers Hyderabad
# 1524  11414  IPL-2019  Visakhapatnam  10-05-2019       Delhi Capitals
# 1525  11414  IPL-2019  Visakhapatnam  10-05-2019       Delhi Capitals
# 1526  11415  IPL-2019      Hyderabad  12-05-2019       Mumbai Indians
# 1527  11415  IPL-2019      Hyderabad  12-05-2019       Mumbai Indians
#
#                             team2                  toss_winner toss_decision  \
# ...

# %%
match['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams=['Sunrisers Hyderabad',
       'Mumbai Indians',
       'Gujarat Lions',
       'Rising Pune Supergiant',
       'Royal Challengers Bangalore',
       'Kolkata Knight Riders',
       'Delhi Daredevils',
       'Kings XI Punjab',
       'Chennai Super Kings',
       'Rajasthan Royals'
       'Delhi Capitals']

# %%
match['team1'] = match['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match['team2'] = match['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match['team1'] = match['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match['team2'] = match['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match = match[match['team1'].isin(teams)]
match = match[match['team2'].isin(teams)]

# %%
match.shape
# Out:
# (800, 20)

# %%
match = match[match['dl_applied'] == 0]

# %%
match = match[['match_id','city','winner','total_runs']]

# %%
match
# Out:
#       match_id       city                  winner  total_runs
# 0            1  Hyderabad     Sunrisers Hyderabad         207
# 1            1  Hyderabad     Sunrisers Hyderabad         172
# 2            2       Pune  Rising Pune Supergiant         184
# 3            2       Pune  Rising Pune Supergiant         187
# 4            3     Rajkot   Kolkata Knight Riders         183
# ...        ...        ...                     ...         ...
# 1519     11347     Mumbai          Mumbai Indians         137
# 1520     11412    Chennai          Mumbai Indians         136
# 1521     11412    Chennai          Mumbai Indians         140
# 1526     11415  Hyderabad          Mumbai Indians         152
# 1527     11415  Hyderabad          Mumbai Indians         157
#
# [780 rows x 4 columns]

# %%
deliveries = match.merge(deliveries,on='match_id')

# %%
deliveries= deliveries[deliveries['inning'] == 2]

# %%
deliveries
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 187209     11415  Hyderabad       Mumbai Indians           157       2
# 187210     11415  Hyderabad       Mumbai Indians           157       2
# 187211     11415  Hyderabad       Mumbai Indians           157       2
# 187212     11415  Hyderabad       Mumbai Indians           157       2
# 187213     11415  Hyderabad       Mumbai Indians           157       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
deliveries['current_score'] = deliveries.groupby('match_id')['total_runs_x'].cumsum()

# %%
deliveries['balls_left'] = 126 - (deliveries['over']*6 + deliveries['ball'])

# %%
deliveries
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 187209     11415  Hyderabad       Mumbai Indians           157       2
# 187210     11415  Hyderabad       Mumbai Indians           157       2
# 187211     11415  Hyderabad       Mumbai Indians           157       2
# 187212     11415  Hyderabad       Mumbai Indians           157       2
# 187213     11415  Hyderabad       Mumbai Indians           157       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
deliveries['player_dismissed'] = deliveries['player_dismissed'].fillna("0")
deliveries['player_dismissed'] = deliveries['player_dismissed'].apply(lambda x:x if x == "0" else "1")
deliveries['player_dismissed'] = deliveries['player_dismissed'].astype('int')
wickets = deliveries.groupby('match_id')['player_dismissed'].cumsum().values
deliveries['wickets'] = 10 - wickets
deliveries.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# 125       CH Gayle  ...            0            1           0             1
# ...

# %%
deliveries.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# 125       CH Gayle  ...            0            1           0             1
# ...

# %%
deliveries['crr'] = (deliveries['current_score']*6)/(120 - deliveries['balls_left'])

# %%
deliveries
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 187209     11415  Hyderabad       Mumbai Indians           157       2
# 187210     11415  Hyderabad       Mumbai Indians           157       2
# 187211     11415  Hyderabad       Mumbai Indians           157       2
# 187212     11415  Hyderabad       Mumbai Indians           157       2
# 187213     11415  Hyderabad       Mumbai Indians           157       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
deliveries['crr'] = (deliveries['batsman_runs']*6)/deliveries['balls_left']

# %%
deliveries
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 187209     11415  Hyderabad       Mumbai Indians           157       2
# 187210     11415  Hyderabad       Mumbai Indians           157       2
# 187211     11415  Hyderabad       Mumbai Indians           157       2
# 187212     11415  Hyderabad       Mumbai Indians           157       2
# 187213     11415  Hyderabad       Mumbai Indians           157       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
deliveries['result'] = deliveries.apply(result,axis=1)

# %%
final = deliveries[['batting_team','bowling_team','city','balls_left','wickets','total_runs_x','crr','result']]

# %%
final = final.sample(final.shape[0])

# %%
final.sample()
# Out:
#                batting_team     bowling_team  city  balls_left  wickets  \
# 169501  Chennai Super Kings  Kings XI Punjab  Pune          30        6
#
#         total_runs_x  crr  result
# 169501           164  0.8       1

# %%
final.dropna(inplace=True)

# %%
final = final[final['balls_left'] != 0]

# %%
X= final.iloc[:,:-1]
y = final.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                        batting_team                 bowling_team  \
# 170733        Kolkata Knight Riders          Sunrisers Hyderabad
# 79112                Mumbai Indians          Chennai Super Kings
# 62970               Deccan Chargers              Kings XI Punjab
# 92178   Royal Challengers Bangalore              Deccan Chargers
# 93985           Chennai Super Kings               Mumbai Indians
# ...                             ...                          ...
# 18074         Kolkata Knight Riders              Kings XI Punjab
# 81555         Kolkata Knight Riders              Kings XI Punjab
# 89788               Kings XI Punjab              Deccan Chargers
# 150685              Kings XI Punjab               Mumbai Indians
# 120531          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                  city  balls_left  wickets  total_runs_x       crr
# 170733        Kolkata          25       -5           163  0.240000
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7309042286478356

# %%
pipe.predict_proba(X_test)[10]
# Out:
# array([0.4832381, 0.5167619])

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Gujarat Lions',
#  'Rising Pune Supergiant',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Delhi Daredevils',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan RoyalsDelhi Capitals']

# %%
deliveries['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Mumbai', 'Kolkata',
#        'Bangalore', 'Chandigarh', 'Kanpur', 'Chennai', 'Cape Town',
#        'Port Elizabeth', 'Durban', 'East London', 'Johannesburg',
#        'Centurion', 'Kimberley', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Ranchi', 'Delhi', 'Abu Dhabi', nan, 'Sharjah',
#        'Bengaluru', 'Mohali'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
